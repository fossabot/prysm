# %%
from prysm import FringeZernike, StandardZernike
import numpy as np
# %matplotlib inline

# %%
# use named terms
myPupil = FringeZernike(Z5=1)

# the base can be user-specified
myPupil_base1 = FringeZernike(Z6=1, base=1)

# pass an array of zernike terms starting from 0.  specify the pupil diameter in mm and wavelength in um
wavefront_coefs = np.random.rand(48) - 0.5
myPupil2 = FringeZernike(wavefront_coefs, epd=10, wavelength=0.55)

# use normalized form of zernikes and specify in units of um, units can be latex strings or nm/um
myPupil3 = FringeZernike(Z4=1, Z6=1, Z8=1, Z10=1, rms_norm=True, opd_unit='um', samples=512)
print('myPupil3 has RMS wfe of:')
print(myPupil3.rms) #should be sqrt(1+1+1+1) = sqrt(4) = 2
print('')
# specify number of samples across pupil
myPupil4 = FringeZernike(wavefront_coefs, samples=1024)

#pupils can be plotted in a variety of ways
## an interferogram
myPupil.interferogram()
## an X,Y trace through the pupil phase
myPupil2.plot_slice_xy()
## a 2d phase map
myPupil3.plot2d()
## interferograms can have any number of passes and any level of visibility
myPupil4.interferogram(visibility=0.75, passes=2)

# the __repr__ for a FZ pupil contains the wavefront breakdown
print(myPupil2)
# Out:
# myPupil3 has RMS wfe of:
# 1.99881502013
#
# Fringe Zernike description with:
# 	-0.063 Z0  - Piston / Bias
# 	+0.160 Z1  - Tilt X
# 	-0.266 Z2  - Tilt Y
# 	+0.160 Z3  - Defocus / Power
# 	-0.159 Z4  - Primary Astigmatism 00deg
# 	-0.156 Z5  - Primary Astigmatism 45deg
# 	+0.440 Z6  - Primary Coma X
# 	+0.097 Z7  - Primary Coma Y
# 	+0.169 Z8  - Primary Spherical
# 	+0.103 Z9  - Primary Trefoil X
# 	-0.167 Z10 - Primary Trefoil Y
# 	+0.242 Z11 - Secondary Astigmatism 00deg
# 	-0.393 Z12 - Secondary Astigmatism 45deg
# 	-0.287 Z13 - Secondary Coma X
# 	+0.490 Z14 - Secondary Coma Y
# 	+0.165 Z15 - Secondary Spherical
# 	-0.089 Z16 - Primary Tetrafoil X
# 	-0.264 Z17 - Primary Tetrafoil Y
# 	-0.462 Z18 - Secondary Trefoil X
# 	-0.228 Z19 - Secondary Trefoil Y
# 	-0.471 Z20 - Tertiary Astigmatism 00deg
# 	+0.024 Z21 - Tertiary Astigmatism 45deg
# 	-0.111 Z22 - Tertiary Coma X
# 	-0.418 Z23 - Tertiary Coma Y
# 	+0.005 Z24 - Tertiary Spherical
# 	+0.327 Z25 - Pentafoil X
# 	+0.056 Z26 - Pentafoil Y
# 	+0.477 Z27 - Secondary Tetrafoil X
# 	+0.149 Z28 - Secondary Tetrafoil Y
# 	-0.183 Z29 - Tertiary Trefoil X
# 	-0.035 Z30 - Tertiary Trefoil Y
# 	+0.410 Z31 - Quarternary Astigmatism 00deg
# 	+0.356 Z32 - Quarternary Astigmatism 45deg
# 	-0.314 Z33 - Quarternary Coma X
# 	+0.029 Z34 - Quarternary Coma Y
# 	+0.059 Z35 - Quarternary Spherical
# 	-0.426 Z36 - Primary Hexafoil X
# 	-0.054 Z37 - Primary Hexafoil Y
# 	+0.061 Z38 - Secondary Pentafoil X
# 	-0.017 Z39 - Secondary Pentafoil Y
# 	-0.138 Z40 - Tertiary Tetrafoil X
# 	-0.489 Z41 - Tertiary Tetrafoil Y
# 	+0.478 Z42 - Quaternary Trefoil X
# 	+0.233 Z43 - Quaternary Trefoil Y
# 	+0.104 Z44 - Quinternary Astigmatism 00deg
# 	-0.388 Z45 - Quinternary Astigmatism 45deg
# 	-0.378 Z46 - Quinternary Coma X
# 	-0.274 Z47 - Quinternary Coma Y
# 	3.426 PV, 0.517 RMS

# %%
# we can also use Standard Zernikes
std_pup = StandardZernike(wavefront_coefs, samples=512)
std_pup.interferogram()
print(std_pup)
# Out:
# Standard Zernike description with:
# 	-0.063 Z0  - Piston / Bias
# 	+0.160 Z1  - Tilt X
# 	-0.266 Z2  - Tilt Y
# 	+0.160 Z3  - Primary Astigmatism 00deg
# 	-0.159 Z4  - Defocus / Power
# 	-0.156 Z5  - Primary Astigmatism 45deg
# 	+0.440 Z6  - Primary Trefoil X
# 	+0.097 Z7  - Primary Coma X
# 	+0.169 Z8  - Primary Coma Y
# 	+0.103 Z9  - Primary Trefoil Y
# 	-0.167 Z10 - Primary Tetrafoil X
# 	+0.242 Z11 - Secondary Astigmatism 00deg
# 	-0.393 Z12 - Primary Spherical
# 	-0.287 Z13 - Secondary Astigmatism 45deg
# 	+0.490 Z14 - Primary Tetrafoil Y
# 	+0.165 Z15 - Primary Pentafoil X
# 	-0.089 Z16 - Secondary Trefoil X
# 	-0.264 Z17 - Secondary Coma X
# 	-0.462 Z18 - Secondary Coma Y
# 	-0.228 Z19 - Secondary Trefoil Y
# 	-0.471 Z20 - Primary Pentafoil Y
# 	+0.024 Z21 - Primary Hexafoil X
# 	-0.111 Z22 - Secondary Tetrafoil X
# 	-0.418 Z23 - Tertiary Astigmatism 00deg
# 	+0.005 Z24 - Secondary Spherical
# 	+0.327 Z25 - Tertariary Astigmatism 45deg
# 	+0.056 Z26 - Secondary Tetrafoil Y
# 	+0.477 Z27 - Primary Hexafoil Y
# 	+0.149 Z28 - Primary Heptafoil X
# 	-0.183 Z29 - Secondary Pentafoil X
# 	-0.035 Z30 - Tertiary Trefoil X
# 	+0.410 Z31 - Tertiary Coma X
# 	+0.356 Z32 - Tertiary Coma Y
# 	-0.314 Z33 - Tertiary Trefoil Y
# 	+0.029 Z34 - Secondary Pentafoil Y
# 	+0.059 Z35 - Primary Heptafoil Y
# 	-0.426 Z36 - Primary Octafoil X
# 	-0.054 Z37 - Secondary Hexafoil X
# 	+0.061 Z38 - Tertiary Tetrafoil X
# 	-0.017 Z39 - Quarternary Astigmatism 00deg
# 	-0.138 Z40 - Tertiary Spherical
# 	-0.489 Z41 - Quarternary Astigmatism 45deg
# 	+0.478 Z42 - Tertiary Tetrafoil Y
# 	+0.233 Z43 - Secondary Hexafoil Y
# 	+0.104 Z44 - Primary Octafoil Y
# 	-0.388 Z45 - Primary Nonafoil X
# 	-0.378 Z46 - Secondary Heptafoil X
# 	-0.274 Z47 - Tertiary Pentafoil X
# 	5.637 PV, 0.858 RMS

# %%
ZZ = FringeZernike(Z8=1)
ZZ.plot_slice_xy()
# Out:
# (<matplotlib.figure.Figure at 0x1cbefd05d68>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1cbef8f2da0>)
