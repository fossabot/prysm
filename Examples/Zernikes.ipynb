# %%
# add ../prysm to the system path so it is found by Python -- this is not needed if you install the module
import sys
sys.path.append('..')

from prysm import FringeZernike
import numpy as np
# %matplotlib inline

# %%
# use named terms
myPupil = FringeZernike(Z5=1)

# pass an array of zernike terms starting from 0.  specify the pupil diameter in mm and wavelength in um
wavefront_coefs = np.random.rand(36)
myPupil2 = FringeZernike(wavefront_coefs, epd=10, wavelength=0.55)

# use normalized form of zernikes and specify in units of um, units can be latex strings or nm/um
myPupil3 = FringeZernike(Z4=1, Z6=1, Z8=1, Z10=1, rms_norm=True, opd_unit='um', samples=512)
print('myPupil3 has RMS wfe of:')
print(myPupil3.rms) #should be sqrt(1+1+1+1) = sqrt(4) = 2
print('')
# specify number of samples across pupil
myPupil4 = FringeZernike(wavefront_coefs, samples=1024)

#pupils can be plotted in a variety of ways
## an interferogram
myPupil.interferogram()
## a 2d phase map
myPupil2.plot2d()
## an X,Y trace through the pupil phase
myPupil3.plot_slice_xy()
## interferograms can have any number of passes and any level of visibility
myPupil4.interferogram(visibility=0.5, passes=2)

# the __repr__ for a FZ pupil contains the wavefront breakdown
print(myPupil2)
# Out:
# myPupil3 has RMS wfe of:
# 1.99881502013
#
# Fringe Zernike description with:
# 	0.567 Z0  - Piston / Bias
# 	0.769 Z1  - Tilt X
# 	0.451 Z2  - Tilt Y
# 	0.596 Z3  - Defocus / Power
# 	0.331 Z4  - Primary Astigmatism 00deg
# 	0.710 Z5  - Primary Astigmatism 45deg
# 	0.204 Z6  - Primary Coma X
# 	0.846 Z7  - Primary Coma Y
# 	0.329 Z8  - Primary Spherical
# 	0.523 Z9  - Primary Trefoil X
# 	0.215 Z10 - Primary Trefoil Y
# 	0.146 Z11 - Secondary Astigmatism 00deg
# 	0.006 Z12 - Secondary Astigmatism 45deg
# 	0.117 Z13 - Secondary Coma X
# 	0.596 Z14 - Secondary Coma Y
# 	0.840 Z15 - Secondary Spherical
# 	0.562 Z16 - Primary Tetrafoil X
# 	0.009 Z17 - Primary Tetrafoil Y
# 	0.349 Z18 - Secondary Trefoil X
# 	0.686 Z19 - Secondary Trefoil Y
# 	0.442 Z20 - Tertiary Astigmatism 00deg
# 	0.341 Z21 - Tertiary Astigmatism 45deg
# 	0.950 Z22 - Tertiary Coma X
# 	0.205 Z23 - Tertiary Coma Y
# 	0.261 Z24 - Tertiary Spherical
# 	0.905 Z25 - Pentafoil X
# 	0.174 Z26 - Pentafoil Y
# 	0.421 Z27 - Secondary Tetrafoil X
# 	0.213 Z28 - Secondary Tetrafoil Y
# 	0.519 Z29 - Tertiary Trefoil X
# 	0.050 Z30 - Tertiary Trefoil Y
# 	0.251 Z31 - Quarternary Astigmatism 00deg
# 	0.477 Z32 - Quarternary Astigmatism 45deg
# 	0.591 Z33 - Quarternary Coma X
# 	0.734 Z34 - Quarternary Coma Y
# 	0.952 Z35 - Quarternary Spherical
# 	17.019 PV, 1.815 RMS
