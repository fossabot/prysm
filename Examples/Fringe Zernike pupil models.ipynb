# %%
# add ../code6 to the system path so it is found by Python -- this is not needed if you install the module
import sys
sys.path.append('..')

from code6 import FringeZernike
import numpy as np
# %matplotlib inline

# %%
# use named terms
myPupil = FringeZernike(Z5=1)

# pass an array of zernike terms starting from 0.  specify the pupil diameter in mm and wavelength in um
wavefront_coefs = np.random.rand(36)
myPupil2 = FringeZernike(wavefront_coefs, epd=10, wavelength=0.55)

# use normalized form of zernikes and specify in units of um, units can be latex strings or nm/um
myPupil3 = FringeZernike(Z29=1, rms_norm=True, opd_unit='nm')

# specify number of samples across pupil
myPupil4 = FringeZernike(wavefront_coefs, samples=1024)

#pupils can be plotted in a variety of ways
## an interferogram
myPupil.interferogram()
# a 2d phase map
myPupil2.plot2d()
# an X,Y trace through the pupil phase
myPupil3.plot_slice_xy()
# interferograms can have any number of passes and any level of visibility
myPupil4.interferogram(visibility=0.5, passes=2)

print(myPupil2)
# Out:
# Fringe Zernike description with:
# 	(0.7075850122788766, 'Z0  - Piston / Bias')
# 	(0.44500658377356794, 'Z1  - Tilt X')
# 	(0.76557938473770448, 'Z2  - Tilt Y')
# 	(0.67362866349772876, 'Z3  - Defocus / Power')
# 	(0.10963135451684691, 'Z4  - Primary Astigmatism X')
# 	(0.20958863601517386, 'Z5  - Primary Astigmatism Y')
# 	(0.19120147011252231, 'Z6  - Primary Coma X')
# 	(0.73790363523265101, 'Z7  - Primary Coma Y')
# 	(0.9833475059148491, 'Z8  - Primary Spherical')
# 	(0.77881954682672982, 'Z9  - Primary Trefoil X')
# 	(0.65050618197958088, 'Z10 - Primary Trefoil Y')
# 	(0.29383512517984478, 'Z11 - Secondary Astigmatism X')
# 	(0.19444709253032899, 'Z12 - Secondary Astigmatism Y')
# 	(0.99501422957672669, 'Z13 - Secondary Coma X')
# 	(0.87574920523918298, 'Z14 - Secondary Coma X')
# 	(0.46507345709991554, 'Z15 - Secondary Spherical Y')
# 	(0.22054935307549417, 'Z16 - Primary Tetrafoil X')
# 	(0.6643986440454076, 'Z17 - Primary Tetrafoil Y')
# 	(0.72180288336691889, 'Z18 - Secondary Trefoil X')
# 	(0.57710764131489301, 'Z19 - Secondary Trefoil Y')
# 	(0.47112810987196052, 'Z20 - Tertiary Astigmatism X')
# 	(0.4644690725769588, 'Z21 - Tertiary Astigmatism Y')
# 	(0.12167701651982743, 'Z22 - Tertiary Coma X')
# 	(0.19173855577588583, 'Z23 - Tertiary Coma Y')
# 	(0.050322216347682858, 'Z24 - Tertiary Spherical')
# 	(0.27527002108879839, 'Z25 - Pentafoil X')
# 	(0.61262736765472581, 'Z26 - Pentafoil Y')
# 	(0.71597750752268818, 'Z27 - Secondary Tetrafoil X')
# 	(0.067710968368689839, 'Z28 - Secondary Tetrafoil Y')
# 	(0.68105963617722409, 'Z29 - Tertiary Trefoil X')
# 	(0.60910498902009846, 'Z30 - Tertiary Trefoil Y')
# 	(0.22890835705603085, 'Z31 - Quarternary Astigmatism X')
# 	(0.87677927193250171, 'Z32 - Quarternary Astigmatism Y')
# 	(0.012438552604420394, 'Z33 - Quarternary Coma X')
# 	(0.9018539138021755, 'Z34 - Quarternary Coma Y')
# 	(0.64317990112604406, 'Z35 - Quarternary Spherical')
# 	20.613550097300475PV, 1.8852223194691489RMS

# %%
expup = FringeZernike(Z3=1, rms_norm=True, opd_unit='nm')
