# %%
# add ../code6 to the system path so it is found by Python -- this is not needed if you install the module
import sys
sys.path.append('..')

from code6 import FringeZernike
import numpy as np
# %matplotlib inline

# %%
# use named terms
myPupil = FringeZernike(Z5=1)

# pass an array of zernike terms starting from 0.  specify the pupil diameter in mm and wavelength in um
wavefront_coefs = np.random.rand(36)
myPupil2 = FringeZernike(wavefront_coefs, epd=10, wavelength=0.55)

# use normalized form of zernikes and specify in units of um, units can be latex strings or nm/um
myPupil3 = FringeZernike(Z29=1, rms_norm=True, opd_unit='nm')

# specify number of samples across pupil
myPupil4 = FringeZernike(wavefront_coefs, samples=1024)

#pupils can be plotted in a variety of ways
## an interferogram
myPupil.interferogram()
# a 2d phase map
myPupil2.plot2d()
# an X,Y trace through the pupil phase
myPupil3.plot_slice_xy()
# interferograms can have any number of passes and any level of visibility
myPupil4.interferogram(visibility=0.5, passes=2)

print(myPupil2)
# Out:
# Fringe Zernike description with:
# 	(0.12251876654132643, 'Z0  - Piston / Bias')
# 	(0.70016427211149257, 'Z1  - Tilt X')
# 	(0.047438041324625813, 'Z2  - Tilt Y')
# 	(0.83139188868448133, 'Z3  - Defocus / Power')
# 	(0.17813875918495514, 'Z4  - Primary Astigmatism X')
# 	(0.74326204400550522, 'Z5  - Primary Astigmatism Y')
# 	(0.8357126222702469, 'Z6  - Primary Coma X')
# 	(0.54806465537862359, 'Z7  - Primary Coma Y')
# 	(0.65767916108636471, 'Z8  - Primary Spherical')
# 	(0.31521252081097284, 'Z9  - Primary Trefoil X')
# 	(0.64164710912022749, 'Z10 - Primary Trefoil Y')
# 	(0.47745346251932175, 'Z11 - Secondary Astigmatism X')
# 	(0.35694344401302136, 'Z12 - Secondary Astigmatism Y')
# 	(0.55608920091719305, 'Z13 - Secondary Coma X')
# 	(0.90076423267824868, 'Z14 - Secondary Coma X')
# 	(0.21630555983071897, 'Z15 - Secondary Spherical Y')
# 	(0.91584513791135125, 'Z16 - Primary Tetrafoil X')
# 	(0.24354307785405738, 'Z17 - Primary Tetrafoil Y')
# 	(0.62713504991830427, 'Z18 - Secondary Trefoil X')
# 	(0.17680580511870969, 'Z19 - Secondary Trefoil Y')
# 	(0.64547849809141966, 'Z20 - Tertiary Astigmatism X')
# 	(0.28202800163312425, 'Z21 - Tertiary Astigmatism Y')
# 	(0.048584699472820847, 'Z22 - Tertiary Coma X')
# 	(0.68865091718386229, 'Z23 - Tertiary Coma Y')
# 	(0.75697000581516694, 'Z24 - Tertiary Spherical')
# 	(0.70977529480782486, 'Z25 - Pentafoil X')
# 	(0.39957803377921031, 'Z26 - Pentafoil Y')
# 	(0.23920662089713152, 'Z27 - Secondary Tetrafoil X')
# 	(0.26768490792613042, 'Z28 - Secondary Tetrafoil Y')
# 	(0.78314004998470621, 'Z29 - Tertiary Trefoil X')
# 	(0.93309812145011173, 'Z30 - Tertiary Trefoil Y')
# 	(0.47022318358450144, 'Z31 - Quarternary Astigmatism X')
# 	(0.60097471948223935, 'Z32 - Quarternary Astigmatism Y')
# 	(0.067829636899948809, 'Z33 - Quarternary Coma X')
# 	(0.98845173708117695, 'Z34 - Quarternary Coma Y')
# 	(0.55949382552280469, 'Z35 - Quarternary Spherical')
# 	0PV, 0RMS
